# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./dataearnings-competitors-data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pd.read_csv('./earnings-competitors-data.csv')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
kazancToplama = data.groupby('Kişi')['Kazanılan Para'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 kazancToplama = data.groupby('Kişi')['Kazanılan Para'].sum().reset_index()
#
# NameError: name 'data' is not defined

# %%
toplamKazanc = kazancToplama['Kazanılan Para'].sum()

# %%
kazancToplama['Yüzde'] = kazancToplama['Kazanılan Para'] / toplamKazanc * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 kazancToplama['Yüzde'] = kazancToplama['Kazanılan Para'] / toplamKazanc * 100
#
# NameError: name 'kazancToplama' is not defined

# %%
plt.pie(kazancToplama['Yüzde'], labels=kazancToplama['Kişi'], autopct='%1.1f%%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.pie(kazancToplama['Yüzde'], labels=kazancToplama['Kişi'], autopct='%1.1f%%')
#
# NameError: name 'kazancToplama' is not defined

# %%
plt.title('Kazanılan Para Dağılımı')
# Out:
# Text(0.5, 1.0, 'Kazanılan Para Dağılımı')

# %%
plt.axis('equal')
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
for index, row in kazancToplama.iterrows():
    print(f"{row['Kişi']} - %{row['Yüzde']:.2f} - {row['Kazanılan Para']:.2f} lira")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for index, row in kazancToplama.iterrows():
#       2     print(f"{row['Kişi']} - %{row['Yüzde']:.2f} - {row['Kazanılan Para']:.2f} lira")
#
# NameError: name 'kazancToplama' is not defined
